# %%
import numpy as np
import pandas as pd

# %%
df_header = pd.read_excel('header_img.xlsx',sheet_name='IMG',usecols='B')

# %%
cols = df_header['Unnamed: 1'].tolist()

# %%
df_data= pd.read_csv('img.txt',skiprows=1,skipfooter=1,engine='python',sep=';')

# %%
df_data.columns = cols

# %%
df_data
# Out:
#          ID_PRET       ID_CREANCE DEVISE  NATURE_TAUX  TYPE_TAUX  \
# 0   DOS016962000   DOS016962000/4    EUR            3        NaN
# 1   DOS017074100   DOS017074100/4    EUR            3        NaN
# 2   DOS019021200  DOS019021200/15    EUR            3        NaN
# 3   DOS014087200  DOS014087200/23    EUR            3        NaN
# 4   DOS014087200  DOS014087200/27    EUR            3        NaN
# 5   DOS014168100   DOS014168100/8    EUR            3        NaN
# 6   DOS019822100   DOS019822100/4    EUR            3        NaN
# 7   DOS020383900   DOS020383900/4    EUR            3        NaN
# 8   DOS020576300   DOS020576300/7    EUR            3        NaN
# 9   DOS014340900   DOS014340900/4    EUR            3        NaN
# 10  DOS018376800   DOS018376800/4    EUR            3        NaN
# 11  DOS013966800   DOS013966800/4    EUR            3        NaN
# 12  DOS014087200  DOS014087200/13    EUR            3        NaN
# ...
